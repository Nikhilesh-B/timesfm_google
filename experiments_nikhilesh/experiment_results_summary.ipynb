# %% [markdown]
# # TimesFM vs classical baselines — results dashboard
#
# This notebook **reads the CSVs** written by the experiment notebooks in `output/` and shows:
#
# - one **combined table** (all scenarios),
# - **per-experiment** tables when useful,
# - a **bar chart** of MSE (lower is better),
# - a **Δ MSE** column: `TimesFM − baseline` ( **negative** ⇒ TimesFM wins on MSE ).
#
# **Expected files** (run the other notebooks first if a file is missing):
# `ar_vs_timesfm_results.csv`, `ma_vs_timesfm_results.csv`, `arma_vs_timesfm_results.csv`, `seasonal_airline_vs_timesfm_results.csv`, `hamilton_switching_vs_timesfm_results.csv`.

# %% [markdown]
# ## 1. Paths and imports

# %%
from pathlib import Path

import numpy as np
import pandas as pd

try:
    import matplotlib.pyplot as plt
except ImportError as e:
    raise ImportError("Install matplotlib for charts: pip install matplotlib") from e

HERE = Path.cwd().resolve()
if (HERE / "output").is_dir():
    OUT = HERE / "output"
elif (HERE / "experiments_nikhilesh_experiments" / "output").is_dir():
    OUT = HERE / "experiments_nikhilesh_experiments" / "output"
else:
    OUT = HERE / "output"

# %% [markdown]
# ## 2. Load and normalize each CSV into one long table

# %%
def load_if(path: Path) -> pd.DataFrame | None:
    if not path.is_file():
        return None
    return pd.read_csv(path)


pieces: list[pd.DataFrame] = []

df = load_if(OUT / "ar_vs_timesfm_results.csv")
if df is not None:
    for _, r in df.iterrows():
        pieces.append(
            {
                "Experiment": "AR",
                "Scenario": f"p = {int(r['p_dgp'])}",
                "Baseline": "ARIMA(p,0,0)",
                "MSE baseline": r["mse_ar"],
                "MSE TimesFM": r["mse_timesfm"],
            }
        )

df = load_if(OUT / "ma_vs_timesfm_results.csv")
if df is not None:
    for _, r in df.iterrows():
        pieces.append(
            {
                "Experiment": "MA",
                "Scenario": f"q = {int(r['q_dgp'])}",
                "Baseline": "ARIMA(0,0,q)",
                "MSE baseline": r["mse_ma"],
                "MSE TimesFM": r["mse_timesfm"],
            }
        )

df = load_if(OUT / "arma_vs_timesfm_results.csv")
if df is not None:
    for _, r in df.iterrows():
        pieces.append(
            {
                "Experiment": "ARMA",
                "Scenario": f"(p,q) = ({int(r['p_dgp'])},{int(r['q_dgp'])})",
                "Baseline": "ARIMA(p,0,q)",
                "MSE baseline": r["mse_arma"],
                "MSE TimesFM": r["mse_timesfm"],
            }
        )

df = load_if(OUT / "seasonal_airline_vs_timesfm_results.csv")
if df is not None:
    for _, r in df.iterrows():
        pieces.append(
            {
                "Experiment": "Seasonal (airline)",
                "Scenario": f"m={int(r['seasonal_period'])}, k_first={int(r['k_first'])}",
                "Baseline": "SARIMA(0,1,1)(0,1,1)ₘ",
                "MSE baseline": r["mse_airline_sarimax"],
                "MSE TimesFM": r["mse_timesfm"],
            }
        )

df = load_if(OUT / "hamilton_switching_vs_timesfm_results.csv")
if df is not None:
    for _, r in df.iterrows():
        pieces.append(
            {
                "Experiment": "Markov switching",
                "Scenario": "MS-AR(1) DGP",
                "Baseline": "OLS AR(1)",
                "MSE baseline": r["mse_ols_ar1"],
                "MSE TimesFM": r["mse_timesfm"],
            }
        )

if not pieces:
    raise FileNotFoundError(
        f"No result CSVs found under {OUT}. Run the experiment notebooks first."
    )

summary = pd.DataFrame(pieces)
summary["Δ (TF − baseline)"] = summary["MSE TimesFM"] - summary["MSE baseline"]
summary["TimesFM better (MSE)"] = summary["Δ (TF − baseline)"] < 0
summary
# Out:
#            Experiment          Scenario               Baseline  MSE baseline  \
# 0                  AR             p = 2           ARIMA(p,0,0)      0.631848
# 1                  AR             p = 5           ARIMA(p,0,0)      1.117969
# 2                  MA             q = 2           ARIMA(0,0,q)      0.623531
# 3                  MA             q = 5           ARIMA(0,0,q)      1.182167
# 4                ARMA     (p,q) = (2,2)           ARIMA(p,0,q)      0.672455
# 5                ARMA     (p,q) = (2,5)           ARIMA(p,0,q)      0.991613
# 6                ARMA     (p,q) = (5,2)           ARIMA(p,0,q)      1.292906
# 7                ARMA     (p,q) = (5,5)           ARIMA(p,0,q)      1.165064
# 8  Seasonal (airline)  m=12, k_first=37  SARIMA(0,1,1)(0,1,1)ₘ      0.915665
# 9    Markov switching      MS-AR(1) DGP              OLS AR(1)      1.254519
#
#    MSE TimesFM  Δ (TF − baseline)  TimesFM better (MSE)
# 0     0.655677           0.023829                 False
# 1     0.984800          -0.133169                  True
# 2     0.679893           0.056361                 False
# 3     1.089988          -0.092179                  True
# 4     0.693744           0.021289                 False
# 5     0.952549          -0.039065                  True
# 6     1.011070          -0.281836                  True
# 7     0.960869          -0.204195                  True
# 8     0.811261          -0.104404                  True
# 9     1.306230           0.051710                 False

# %% [markdown]
# ## 3. Styled table (sort by experiment, then scenario)

# %%
display_df = summary.sort_values(["Experiment", "Scenario"]).reset_index(drop=True)
fmt = {c: "{:.4f}" for c in ["MSE baseline", "MSE TimesFM", "Δ (TF − baseline)"]}
styled = (
    display_df.style.format(fmt)
    .background_gradient(subset=["MSE baseline", "MSE TimesFM"], cmap="YlOrRd_r")
    .set_properties(**{"text-align": "right"}, subset=["MSE baseline", "MSE TimesFM", "Δ (TF − baseline)"])
)
styled
# Out:
# <style type="text/css">
# #T_bfc9b_row0_col3 {
#   background-color: #860026;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row0_col4, #T_bfc9b_row6_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row0_col5, #T_bfc9b_row1_col5, #T_bfc9b_row2_col5, #T_bfc9b_row3_col5, #T_bfc9b_row4_col5, #T_bfc9b_row5_col5, #T_bfc9b_row6_col5, #T_bfc9b_row7_col5, #T_bfc9b_row8_col5, #T_bfc9b_row9_col5 {
#   text-align: right;
# }
# #T_bfc9b_row1_col3 {
#   background-color: #fed673;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row1_col4 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row2_col3 {
#   background-color: #a20026;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row2_col4 {
#   background-color: #9b0026;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row3_col3 {
#   background-color: #fd9c42;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row3_col4 {
#   background-color: #fd7636;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row4_col3, #T_bfc9b_row8_col4 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row4_col4 {
#   background-color: #fd9a42;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row5_col3 {
#   background-color: #fee38b;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row5_col4 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row6_col4 {
#   background-color: #910026;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row7_col3 {
#   background-color: #ffe793;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row7_col4 {
#   background-color: #febf5a;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row8_col3 {
#   background-color: #fff7b9;
#   color: #000000;
#   text-align: right;
# }
# #T_bfc9b_row9_col3 {
#   background-color: #fc6c33;
#   color: #f1f1f1;
#   text-align: right;
# }
# #T_bfc9b_row9_col4 {
#   background-color: #e0181d;
#   color: #f1f1f1;
#   text-align: right;
# }
# </style>
# <table id="T_bfc9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfc9b_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_bfc9b_level0_col1" class="col_heading level0 col1" >Scenario</th>
#       <th id="T_bfc9b_level0_col2" class="col_heading level0 col2" >Baseline</th>
#       <th id="T_bfc9b_level0_col3" class="col_heading level0 col3" >MSE baseline</th>
#       <th id="T_bfc9b_level0_col4" class="col_heading level0 col4" >MSE TimesFM</th>
#       <th id="T_bfc9b_level0_col5" class="col_heading level0 col5" >Δ (TF − baseline)</th>
#       <th id="T_bfc9b_level0_col6" class="col_heading level0 col6" >TimesFM better (MSE)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfc9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfc9b_row0_col0" class="data row0 col0" >AR</td>
#       <td id="T_bfc9b_row0_col1" class="data row0 col1" >p = 2</td>
#       <td id="T_bfc9b_row0_col2" class="data row0 col2" >ARIMA(p,0,0)</td>
#       <td id="T_bfc9b_row0_col3" class="data row0 col3" >0.6318</td>
#       <td id="T_bfc9b_row0_col4" class="data row0 col4" >0.6557</td>
#       <td id="T_bfc9b_row0_col5" class="data row0 col5" >0.0238</td>
#       <td id="T_bfc9b_row0_col6" class="data row0 col6" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bfc9b_row1_col0" class="data row1 col0" >AR</td>
#       <td id="T_bfc9b_row1_col1" class="data row1 col1" >p = 5</td>
#       <td id="T_bfc9b_row1_col2" class="data row1 col2" >ARIMA(p,0,0)</td>
#       <td id="T_bfc9b_row1_col3" class="data row1 col3" >1.1180</td>
#       <td id="T_bfc9b_row1_col4" class="data row1 col4" >0.9848</td>
#       <td id="T_bfc9b_row1_col5" class="data row1 col5" >-0.1332</td>
#       <td id="T_bfc9b_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bfc9b_row2_col0" class="data row2 col0" >ARMA</td>
#       <td id="T_bfc9b_row2_col1" class="data row2 col1" >(p,q) = (2,2)</td>
#       <td id="T_bfc9b_row2_col2" class="data row2 col2" >ARIMA(p,0,q)</td>
#       <td id="T_bfc9b_row2_col3" class="data row2 col3" >0.6725</td>
#       <td id="T_bfc9b_row2_col4" class="data row2 col4" >0.6937</td>
#       <td id="T_bfc9b_row2_col5" class="data row2 col5" >0.0213</td>
#       <td id="T_bfc9b_row2_col6" class="data row2 col6" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bfc9b_row3_col0" class="data row3 col0" >ARMA</td>
#       <td id="T_bfc9b_row3_col1" class="data row3 col1" >(p,q) = (2,5)</td>
#       <td id="T_bfc9b_row3_col2" class="data row3 col2" >ARIMA(p,0,q)</td>
#       <td id="T_bfc9b_row3_col3" class="data row3 col3" >0.9916</td>
#       <td id="T_bfc9b_row3_col4" class="data row3 col4" >0.9525</td>
#       <td id="T_bfc9b_row3_col5" class="data row3 col5" >-0.0391</td>
#       <td id="T_bfc9b_row3_col6" class="data row3 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bfc9b_row4_col0" class="data row4 col0" >ARMA</td>
#       <td id="T_bfc9b_row4_col1" class="data row4 col1" >(p,q) = (5,2)</td>
#       <td id="T_bfc9b_row4_col2" class="data row4 col2" >ARIMA(p,0,q)</td>
#       <td id="T_bfc9b_row4_col3" class="data row4 col3" >1.2929</td>
#       <td id="T_bfc9b_row4_col4" class="data row4 col4" >1.0111</td>
#       <td id="T_bfc9b_row4_col5" class="data row4 col5" >-0.2818</td>
#       <td id="T_bfc9b_row4_col6" class="data row4 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bfc9b_row5_col0" class="data row5 col0" >ARMA</td>
#       <td id="T_bfc9b_row5_col1" class="data row5 col1" >(p,q) = (5,5)</td>
#       <td id="T_bfc9b_row5_col2" class="data row5 col2" >ARIMA(p,0,q)</td>
#       <td id="T_bfc9b_row5_col3" class="data row5 col3" >1.1651</td>
#       <td id="T_bfc9b_row5_col4" class="data row5 col4" >0.9609</td>
#       <td id="T_bfc9b_row5_col5" class="data row5 col5" >-0.2042</td>
#       <td id="T_bfc9b_row5_col6" class="data row5 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bfc9b_row6_col0" class="data row6 col0" >MA</td>
#       <td id="T_bfc9b_row6_col1" class="data row6 col1" >q = 2</td>
#       <td id="T_bfc9b_row6_col2" class="data row6 col2" >ARIMA(0,0,q)</td>
#       <td id="T_bfc9b_row6_col3" class="data row6 col3" >0.6235</td>
#       <td id="T_bfc9b_row6_col4" class="data row6 col4" >0.6799</td>
#       <td id="T_bfc9b_row6_col5" class="data row6 col5" >0.0564</td>
#       <td id="T_bfc9b_row6_col6" class="data row6 col6" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bfc9b_row7_col0" class="data row7 col0" >MA</td>
#       <td id="T_bfc9b_row7_col1" class="data row7 col1" >q = 5</td>
#       <td id="T_bfc9b_row7_col2" class="data row7 col2" >ARIMA(0,0,q)</td>
#       <td id="T_bfc9b_row7_col3" class="data row7 col3" >1.1822</td>
#       <td id="T_bfc9b_row7_col4" class="data row7 col4" >1.0900</td>
#       <td id="T_bfc9b_row7_col5" class="data row7 col5" >-0.0922</td>
#       <td id="T_bfc9b_row7_col6" class="data row7 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bfc9b_row8_col0" class="data row8 col0" >Markov switching</td>
#       <td id="T_bfc9b_row8_col1" class="data row8 col1" >MS-AR(1) DGP</td>
#       <td id="T_bfc9b_row8_col2" class="data row8 col2" >OLS AR(1)</td>
#       <td id="T_bfc9b_row8_col3" class="data row8 col3" >1.2545</td>
#       <td id="T_bfc9b_row8_col4" class="data row8 col4" >1.3062</td>
#       <td id="T_bfc9b_row8_col5" class="data row8 col5" >0.0517</td>
#       <td id="T_bfc9b_row8_col6" class="data row8 col6" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bfc9b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td i

# %% [markdown]
# ## 4. Chart — MSE by scenario
#
# Each **label** is one row of the table; **two bars** per label (baseline vs TimesFM).

# %%
plot_df = display_df.copy()
plot_df["Label"] = plot_df["Experiment"] + " | " + plot_df["Scenario"]
n = len(plot_df)
fig_h = max(4.0, 0.35 * n)
fig, ax = plt.subplots(figsize=(10, fig_h))
y = np.arange(n)
h = 0.35
ax.barh(y - h / 2, plot_df["MSE baseline"], height=h, label="Baseline", color="#2c5282")
ax.barh(y + h / 2, plot_df["MSE TimesFM"], height=h, label="TimesFM 2.5", color="#c05621")
ax.set_yticks(y)
ax.set_yticklabels(plot_df["Label"], fontsize=9)
ax.set_xlabel("MSE (lower is better)")
ax.legend(loc="lower right")
ax.set_title("One-step MSE: classical baseline vs TimesFM")
ax.grid(axis="x", alpha=0.35)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Optional — export combined CSV
#
# Writes `output/all_experiments_summary.csv` for slides or papers.

# %%
OUT.mkdir(parents=True, exist_ok=True)
save_path = OUT / "all_experiments_summary.csv"
display_df.to_csv(save_path, index=False)
print(save_path)
# Out:
# /Users/nikhileshbelulkar/Documents/timesfm_google/experiments_nikhilesh_experiments/output/all_experiments_summary.csv
